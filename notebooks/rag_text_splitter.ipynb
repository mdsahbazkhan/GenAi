# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
texts="Artificial Intelligence is one of the most powerful technologies of the modern era. It is transforming industries, improving productivity, and changing the way humans interact with machines. From healthcare to education, AI is making systems smarter and more efficient."

# %%
splitter=RecursiveCharacterTextSplitter(chunk_size=50,chunk_overlap=20)

# %%
chunks=splitter.split_text(texts)

# %%
print(chunks)
# Out:
# ['Artificial Intelligence is one of the most', 'is one of the most powerful technologies of the', 'technologies of the modern era. It is', 'modern era. It is transforming industries,', 'industries, improving productivity, and changing', 'and changing the way humans interact with', 'interact with machines. From healthcare to', 'From healthcare to education, AI is making', 'AI is making systems smarter and more efficient.']

# %% [markdown]
# #### Document Text Loader

# %%
from langchain_community.document_loaders import TextLoader,PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader=TextLoader("../data/speech.txt")
texts=loader.load()

# %%
pdfloader= PyPDFLoader("../data/medical_report.pdf")
pdfs=pdfloader.load()

# %%
splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)

# %%
text_chunks=splitter.split_documents(texts)
len(text_chunks)
# Out:
# 65

# %%
# text_chunks

# %%
pdf_chunks=splitter.split_documents(pdfs)
len(pdf_chunks)
# Out:
# 9

# %%
pdf_chunks
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-05-04T07:10:35+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-05-04T07:10:35+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/medical_report.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='Page 1: Patient Information & Overview\nPatient Name: John Doe\nAge: 45\nGender: Male\nDate of Report: 10 October 2025\nHospital: City Care Medical Center\nChief Complaint:\nPersistent fatigue, mild chest discomfort, and shortness of breath for 3 months.\nMedical History:\nHypertension (5 years), Type 2 Diabetes (3 years), No drug allergies.'),
# ...
