# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm=ChatGoogleGenerativeAI(model="gemini-3-flash-preview",streaming=True)

# %%
question="Can you explain me Role of AI Engineer"

# %%
res=llm.stream(question)
for chunk in res:
    print(chunk.text,end="")
# Out:
# An **AI Engineer** is a professional who builds, integrates, and maintains artificial intelligence systems and applications.
#
# Think of an AI Engineer as the **bridge between data science and software engineering.** While a Data Scientist focuses on finding patterns in data and researching new algorithms, an AI Engineer focuses on taking those models and turning them into functional, scalable products.
#
# Here is a detailed breakdown of the role:
#
# ---
#
# ### 1. Key Responsibilities
# The day-to-day tasks of an AI Engineer generally fall into these categories:
#
# *   **Model Selection and Development:** Choosing the right machine learning (ML) models (like Neural Networks, Decision Trees, or Transformers) to solve a specific business problem.
# *   **Data Pipeline Construction:** Building systems that automatically collect, clean, and prepare data so the AI can "learn" from it.
# ...

# %%
from langchain_groq import ChatGroq

llm=ChatGroq(model="llama-3.1-8b-instant",streaming=True)

# %%
question="Can you explain me Role of AI Engineer"

# %%
res=llm.stream(question)
for chunk in res:
    print(chunk.text,end="")
# Out:
# An AI Engineer, also known as a Machine Learning Engineer or Artificial Intelligence Engineer, is a professional responsible for designing, developing, testing, and deploying artificial intelligence (AI) and machine learning (ML) systems. Their primary goal is to create intelligent systems that can learn from data, make decisions, and interact with humans in a way that simulates human-like intelligence.
#
# **Responsibilities of an AI Engineer:**
#
# 1. **Design and Development**: Design and develop AI and ML models, algorithms, and systems that can learn from data, make predictions, and classify objects.
# 2. **Data Preprocessing**: Collect, preprocess, and prepare data for training and testing AI and ML models.
# 3. **Model Training**: Train AI and ML models using various techniques such as supervised learning, unsupervised learning, and reinforcement learning.
# ...
