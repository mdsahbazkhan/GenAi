# %%
from langchain_ollama import ChatOllama

# %%
llm=ChatOllama(model="gemma3:1b")

# %%
res=llm.invoke("What is the capital of Jharkhand?")
print(res.content)
# Out:
# The capital of Jharkhand is ** Ranchi**.
