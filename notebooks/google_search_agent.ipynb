# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
model=ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
agent=create_agent(
    model=model,
    tools=[search.run],
    system_prompt="You are a agent and can search for any questions on google."
)

# %%
question="What won yesterday IPL match?"

# %%
res=agent.invoke({"messages":[{"role":"user","content":question}]})
print(res["messages"][-1].content)
# Out:
# **Yesterday’s (April 15, 2026) IPL match result**
#
# | Match | Venue | Result |
# |-------|-------|--------|
# | Royal Challengers Bengaluru (RCB) vs Lucknow Super Giants (LSG) | M Chinnaswamy Stadium, Bengaluru | **RCB won by 5 wickets** (RCB 149/5, LSG 146/8) |
#
# Royal Challengers Bengaluru chased 147 successfully, securing the win by five wickets.
